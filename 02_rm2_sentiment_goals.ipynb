# %% [markdown]
# # RM2 Sentiment Analysis for Goals
#
# Notebook ini menjalankan pipeline final RM2 dimensi Goals melalui sentiment analysis. Sentimen dipakai sebagai indikator orientasi pesan berbasis distribusi komentar yang teramati, bukan bukti niat psikologis, hubungan komersial, pengaruh kausal, buzzer, atau astroturfing.

# %% [markdown]
# ## Prinsip Metodologis
#
# - RM1, LCN, HCC membership, Louvain, FSA_V, brand labeling RM1, dan Co-Similarity RM1 hanya dibaca sebagai input terlindungi.
# - Final prediction tidak boleh berasal dari rule-based fallback (`ALLOW_RULE_BASED_FINAL = False`).
# - Pipeline membandingkan `minimal_raw` dan `social_normalized`, dua transformer, serta baseline klasik TF-IDF + LinearSVC terkalibrasi.
# - Validasi domain dilakukan sebagai **AI-assisted semantic adjudication** pada development/challenge set dan representative held-out test; `manual_label` tetap kosong untuk validasi manusia mendatang.
# - Goal orientation adalah orientasi pesan berbasis distribusi sentimen komentar yang teramati, bukan bukti niat psikologis, hubungan komersial, pembayaran, atau koordinasi terencana.

# %%
from pathlib import Path
import json
import sys

ROOT = Path.cwd()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from scripts.rm2_sentiment_goals_pipeline import run_pipeline

# %%
result = run_pipeline(ROOT)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RM2 SENTIMENT GOALS PIPELINE COMPLETE
# - selected pipeline: ensemble_A0.00_B0.20_C0.80 (social_normalized)
# - confidence threshold: 0.440
# - comment rows: 33,847
# - HCC comments: 1,009
# - HCC count: 42
# - development macro-F1: 0.6480
# - held-out macro-F1: 0.4394 (95% CI 0.3642-0.5089)
# - sentiment status counts:
# sentiment_status
# Evaluable    23249
# Uncertain     8878
# No Text       1720
# - HCC goal counts:
# goal_orientation
# Promotional / Supportive    25
# Polarized / Contested       16
# Critical / Complaint         1
# - HCC goal confidence counts:
# goal_confidence
# Medium    19
# High      13
# Low       10
# - AI annotation consistency:
#  sample_set  n_comments  raw_agreement  cohen_kappa_ai_self_consistency  disagreement_count  uncertainty_rate  no_text_rate                                                                                     notes
# development         300            1.0                              1.0                   0          0.240000      0.000000 Cohen's kappa measures two-pass AI self-consistency, not human inter-annotator agreement.
#     holdout         300            1.0                              1.0                   0          0.186667      0.016667 Cohen's kappa measures two-pass AI self-consistency, not human inter-annotator agreement.
#    combined         600            1.0                              1.0                   0          0.213333      0.008333 Cohen's kappa measures two-pass AI self-consistency, not human inter-annotator agreement.
# - RM1 protected inputs unchanged: True

# %%
print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# {
#   "selected_candidate": "ensemble_A0.00_B0.20_C0.80",
#   "selected_variant": "social_normalized",
#   "selected_threshold": 0.44,
#   "development_macro_f1": 0.6479541305888611,
#   "holdout_macro_f1": 0.4394011032308905,
#   "holdout_macro_f1_ci": [
#     0.364150350481574,
#     0.5089450495417034
#   ],
#   "comment_rows": 33847,
#   "hcc_comments": 1009,
#   "hcc_goal_counts": {
#     "Promotional / Supportive": 25,
#     "Polarized / Contested": 16,
#     "Critical / Complaint": 1
#   },
#   "goal_confidence_counts": {
#     "Medium": 19,
#     "High": 13,
#     "Low": 10
#   },
#   "low_confidence_hcc": [
#     "1",
#     "2",
#     "16",
#     "20",
#     "45",
#     "50",
#     "75",
#     "87",
#     "103",
#     "132"
#   ],
#   "rm1_unchanged": true
# }

# %% [markdown]
# ## Output Utama
#
# Tabel utama disimpan di `output/rm2_sentiment/tables/`, visualisasi inti di `output/rm2_sentiment/visualisasi/`, dan file Gephi sentimen HCC di `output/rm2_sentiment/gephi/`.
#
# Visualisasi utama dibatasi pada tiga file: `sentiment_validation_confusion_matrix.png`, `sentiment_hcc_vs_nonhcc_100pct.png`, dan `hcc_goal_orientation_confidence.png`. WordCloud tidak digunakan sebagai validasi sentimen.

# %% [markdown]
# ## Batas Interpretasi
#
# - Sentimen hanya indikator orientasi pesan dan kecenderungan narasi.
# - `goal_orientation` tidak membuktikan niat, afiliasi, pembayaran, instruksi, hubungan komersial, pengaruh kausal, buzzer, atau astroturfing.
# - AI-assisted semantic adjudication bukan validasi manusia; independent human validation tetap menjadi keterbatasan metodologis.
# - HCC sudah final dari RM1; sentimen tidak digunakan untuk membentuk HCC.
